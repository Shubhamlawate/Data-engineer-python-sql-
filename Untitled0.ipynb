# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamlawate/Data-engineer-python-sql-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x =[1,2,3,4,5]
y=[21,36,44,51,89]
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv(r"/content/sample_data/data.csv")

# %%
plt.scatter(df['Glucose'],df['BMI'	])
plt.show()

# %%
plt.scatter(df['Age'],df['BMI'	])
plt.show()

# %%
plt.scatter(df['Glucose'],df['Age'	])
plt.show()

# %%
#subplot
plt.subplot(1,2,1)
plt.scatter(df['Glucose'],df['BMI'	])
plt.subplot(1,2,2)
plt.bar(df['Age'],df['BMI'	])
plt.savefig('plot.png')
plt.show()
